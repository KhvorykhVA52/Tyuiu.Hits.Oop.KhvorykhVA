// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта: Спринт ревью #2</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) и реализуйте простое, сложное и множественное наследование

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Employee
{
    public string Name;
    public string Position;
    public double Salary;

    public virtual void PrintInfo()
    {
        Console.WriteLine($"Сотрудник: {Name}, Должность: {Position}, Зарплата: {Salary}");
    }
}

public interface IReportable
{
    string GenerateReport();
}

public interface ITeamLeader
{
    string[] GetTeamMembers();
}

public class Manager : Employee
{
    public string Department;
    
    public override void PrintInfo()
    {
        Console.WriteLine($"Менеджер: {Name}, Должность: {Position}, Зарплата: {Salary}, Отдел: {Department}");
    }
}

public class ProjectManager : Manager, IReportable, ITeamLeader
{
    public string ProjectName;

    public override void PrintInfo()
    {
        Console.WriteLine($"Проектный менеджер: {Name}, Проект: {ProjectName}, Отдел: {Department}, Зарплата: {Salary}");
    }

    public string GenerateReport()
    {
        return $"Отчет по проекту {ProjectName} от менеджера {Name}";
    }

    public string[] GetTeamMembers()
    {
        return new string[] { "Анна", "Борис", "Виктор" };
    }
}
{
    {
        Employee emp = new Employee { Name = "Иван", Position = "Разработчик", Salary = 50000 };
        Manager mgr = new Manager { Name = "Мария", Position = "Менеджер", Salary = 70000, Department = "IT" };
        ProjectManager pm = new ProjectManager { Name = "Алексей", Position = "ПМ", Salary = 90000, Department = "Разработка", ProjectName = "Новый сайт" };

        emp.PrintInfo();
        mgr.PrintInfo();
        pm.PrintInfo();

        Console.WriteLine(pm.GenerateReport());
        
        string[] team = pm.GetTeamMembers();
        Console.WriteLine("Команда: " + string.Join(", ", team));
    }
}
// Out:
// Сотрудник: Иван, Должность: Разработчик, Зарплата: 50000
// Менеджер: Мария, Должность: Менеджер, Зарплата: 70000, Отдел: IT
// Проектный менеджер: Алексей, Проект: Новый сайт, Отдел: Разработка, Зарплата: 90000
// Отчет по проекту Новый сайт от менеджера Алексей
// Команда: Анна, Борис, Виктор
